# %%
from cadastrar import cadastrar
from calcular_media import calcular_media
from verificar import verif

# %%
nome, nota1, nota2 = cadastrar()

# %%
media_final = calcular_media(nota1, nota2)

# %%
status = verif(media_final)

# %%
print(nome, media_final, status)
# Out:
# ronald 10.0 Aprovado
